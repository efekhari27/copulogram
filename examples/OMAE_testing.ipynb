# %% [markdown]
# # Hybrid multivariate distribution estimation
# This study aims at building a multivariate joint distribution presenting a complex dependence structure.
#
# Using non-parametric dependency estimation (Bernstein copula) and both parametric and non-parametric (kde) marginal estimation.

# %%
# %matplotlib inline

# %%
from matplotlib import rc, rcParams, style
#style.use('default')
rcParams['text.usetex'] = True
#rcParams['text.latex.unicode'] = True
rc('font', **{'family': 'Times'})
rc('text', usetex=True)
rc('font', size=18)# Set the default text font size
rc('axes', titlesize=20)# Set the axes title font size
rc('axes', labelsize=18)# Set the axes labels font size
rc('xtick', labelsize=18)# Set the font size for x tick labels
rc('ytick', labelsize=18)# Set the font size for y tick labels
rc('legend', fontsize=18)# Set the legend font size

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import openturns as ot
import openturns.viewer as viewer
import matplotlib.pyplot as plt

# %%
df_processed = pd.read_csv('data/df_ANEMOC_1H.csv')
all_indexes = df_processed.index.values
saved_colomns = ['θ_wind (deg)', 'U_hub (m/s)', 'θ_wave_new (deg)', 'Hs (m)', 'Tp (s)']
df = df_processed.loc[:, saved_colomns]
new_columns = ["$\\theta_{wind}$", "$U$", "$\\theta_{wave}$", "$H_s$", "$T_p$"]
df.columns = new_columns

# %%
len(all_indexes) / 32
# Out:
# 8766.0

# %% [markdown]
# ## SCADA environmental data

# %%
# Monte Carlo sub-sample to make the plots and the fits faster
N = 1000
candidates_indexes = np.random.choice(all_indexes, N, replace=False)
df_candidates = df.loc[candidates_indexes, new_columns]
df_candidates_physical = df.loc[candidates_indexes, new_columns]

# %%
#g = sns.PairGrid(df, corner=True, hue_kws={"alpha": [0.002], "marker": ["."]})
#g = g.map_diag(sns.histplot, bins=20, color='C3')
#g = g.map_lower(plt.scatter, color='C3')
#g.savefig('figures/subsambled_data.jpg');

# %%
a = pd.copy(df_candidates)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/elias/Documents/copulogram/examples/OMAE_testing.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/elias/Documents/copulogram/examples/OMAE_testing.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> a = pd.copy(df_candidates)
#
# File ~/anaconda3/envs/uqwind/lib/python3.9/site-packages/pandas/__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'copy'

# %%
alpha = 0.5
#rasterized=True is not speeding up plots
g = sns.PairGrid(df_candidates , hue_kws={"alpha": [alpha], "marker": ["."]})
g = g.map_diag(sns.histplot, bins=20, color='C3')
g = g.map_lower(plt.scatter, color='C3')

g.data = df_candidates.rank() / N * df_candidates.max().values
g = g.map_upper(plt.scatter, color='C3');
#g.savefig('figures/subsambled_data.jpg', dpi=300);

# %%
break
# Out:
#   Input In [9]
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
g = sns.PairGrid(df_candidates.rank() / N, corner=True, hue_kws={"alpha": [alpha], "marker": ["."]})
g = g.map_diag(sns.histplot, bins=20, color='C3')
g = g.map_lower(plt.scatter, color='C3')
g.savefig('figures/ranked_subsambled_data.jpg', dpi=300);

# %% [markdown]
# ## Marginals estimation

# %%
U_data = ot.Sample(df_candidates["$U$"].values.reshape(-1, 1))
U_dist = ot.WeibullMinFactory().build(U_data)
print(U_dist)
# Visual check 
histo = ot.HistogramFactory().build(U_data, 30).drawPDF()
histo.setTitle("Mean speed fit")
histo.add(U_dist.drawPDF())
histo.setLegends(['data', 'marginal fit'])
histo.setColors(['red', 'blue'])
view = viewer.View(histo)
# Out:
# WeibullMin(beta = 11.4805, alpha = 2.21887, gamma = 0.00222247)

# %%
df_candidates.columns
# Out:
# Index(['$\theta_{wind}$', '$U$', '$\theta_{wave}$', '$H_s$', '$T_p$'], dtype='object')

# %%
Hs_data = ot.Sample(df_candidates["$H_s$"].values.reshape(-1, 1))
Hs_dist = ot.WeibullMinFactory().build(Hs_data)
print(Hs_dist)
# Visual check 
histo = ot.HistogramFactory().build(Hs_data, 30).drawPDF()
histo.setTitle("Wave Hs fit")
histo.add(Hs_dist.drawPDF())
histo.setLegends(['data', 'marginal fit'])
histo.setColors(['red', 'blue'])
view = viewer.View(histo)
# Out:
# WeibullMin(beta = 2.24893, alpha = 1.57753, gamma = 0.33672)
# WRN - Switch to finite difference to compute the gradient at point=[-3.54227,74.3076,0.337289]
# WRN - TNC went to an abnormal point x=[nan,nan,nan] y=[] msg=TNC got a nan input value

# %%
Tp_data = ot.Sample(df_candidates["$T_p$"].values.reshape(-1, 1))
#Tp_dist = ot.LogNormalFactory().build(Tp_data)
kernel = ot.KernelSmoothing()
# Different bandwidth computation 
# (see: http://openturns.github.io/openturns/latest/auto_data_analysis/distribution_fitting/plot_estimate_non_parametric_distribution.html)
silverman_kw = kernel.computeSilvermanBandwidth(Tp_data)
#mixed_kw = kernel.computeMixedBandwidth(Tp_data)
#plugin_kw = kernel.computePluginBandwidth(Tp_data)
print("Silverman bandwidth = {:.2f}".format(silverman_kw[0]))
#print("Mixed bandwidth = {:.2f}".format(mixed_kw[0]))
#print("Plugin bandwidth = {:.2f}".format(plugin_kw[0]))
Tp_kde = kernel.build(Tp_data, silverman_kw)
# Visual check 
histo = ot.HistogramFactory().build(Tp_data, 30).drawPDF()
histo.setTitle("Wave Tp fit")
histo.add(Tp_kde.drawPDF())
histo.setLegends(['data', 'marginal fit'])
histo.setColors(['red', 'blue'])
view = viewer.View(histo)
# Out:
# Silverman bandwidth = 0.25
# WRN - Warning! The distribution number 1 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 848 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 891 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 892 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 893 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 897 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 898 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 902 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 907 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 908 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 909 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 912 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 913 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 916 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 919 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 920 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 921 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 922 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 923 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 924 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 925 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 926 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 927 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 931 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 932 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 933 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 936 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 937 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 945 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 946 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 947 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 948 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 949 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 950 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 951 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 952 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 953 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 954 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 955 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 956 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 957 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 958 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 959 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 960 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 961 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 962 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 963 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 964 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 965 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 966 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 967 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 968 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 969 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 970 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 971 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 972 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 973 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 974 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 975 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 976 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 977 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 978 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 979 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 980 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 981 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 982 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 985 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 986 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 987 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 988 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 989 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 990 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 991 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 992 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 993 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 994 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 995 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 998 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 999 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1000 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1001 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1002 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1003 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1004 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1005 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1006 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1007 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1008 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1009 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1010 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1011 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1014 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1015 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1016 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1017 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1018 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1019 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1020 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1021 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.
# WRN - Warning! The distribution number 1022 has a too small weight=0 for a relative threshold equal to Mixture-SmallWeight=6.95082e-10 with respect to the maximum weight=695.082. It is removed from the collection.

# %%
WaveDir_data = ot.Sample(df_candidates["$\\theta_{wave}$"].values.reshape(-1, 1))
#WaveDir_dist = ot.WeibullMinFactory().build(WaveDir_data)
kernel = ot.KernelSmoothing()
# Different bandwidth computation 
#silverman_kw = kernel.computeSilvermanBandwidth(WaveDir_data)
mixed_kw = kernel.computeMixedBandwidth(WaveDir_data)
#plugin_kw = kernel.computePluginBandwidth(WaveDir_data)
#print("Silverman bandwidth = {:.2f}".format(silverman_kw[0]))
print("Mixed bandwidth = {:.2f}".format(mixed_kw[0]))
#print("Plugin bandwidth = {:.2f}".format(plugin_kw[0]))
WaveDir_kde = kernel.build(WaveDir_data, mixed_kw)
# Visual check 
histo = ot.HistogramFactory().build(WaveDir_data, 30).drawPDF()
histo.setTitle("Wave direction fit")
histo.add(WaveDir_kde.drawPDF())
histo.setLegends(['data', 'marginal fit'])
histo.setColors(['red', 'blue'])
view = viewer.View(histo)
# Out:
# Mixed bandwidth = 2.80

# %%
WindDir_data = ot.Sample(df_candidates["$\\theta_{wind}$"].values.reshape(-1, 1))
#WindDir_dist = ot.WeibullMinFactory().build(WindDir_data)
kernel = ot.KernelSmoothing()
# Different bandwidth computation 
#silverman_kw = kernel.computeSilvermanBandwidth(WindDir_data)
mixed_kw = kernel.computeMixedBandwidth(WindDir_data)
#plugin_kw = kernel.computePluginBandwidth(WindDir_data)
#print("Silverman bandwidth = {:.2f}".format(silverman_kw[0]))
print("Mixed bandwidth = {:.2f}".format(mixed_kw[0]))
#print("Plugin bandwidth = {:.2f}".format(plugin_kw[0]))
WindDir_kde = kernel.build(WindDir_data, mixed_kw)
# Visual check 
histo = ot.HistogramFactory().build(WindDir_data, 30).drawPDF()
histo.setTitle("Wind direction fit")
histo.add(WindDir_kde.drawPDF())
histo.setLegends(['data', 'marginal fit'])
histo.setColors(['red', 'blue'])
view = viewer.View(histo)
# Out:
# Mixed bandwidth = 4.24

# %% [markdown]
# ## Bernstein copula estimation

# %%
K = 100
sample = ot.Sample(df_candidates[new_columns].values)
#ot.BernsteinCopulaFactory().ComputeAMISEBinNumber(sample)
bernstein_copula = ot.BernsteinCopulaFactory().build(sample, K)

# %%
berstein_sample = pd.DataFrame(np.array(bernstein_copula.getSample(N)), columns=new_columns)

# %%
g = sns.PairGrid(berstein_sample, corner=True, hue_kws={"alpha": [alpha], "marker": ["."]})
g = g.map_diag(sns.histplot, bins=20, color='C0')
g = g.map_lower(plt.scatter, color='C0')
g.savefig('figures/ranked_bernstein_simulated.jpg', dpi=300);

# %% [markdown]
# Note that this pairplot on a generated sample is close to the data pairplot in the rank space.

# %% [markdown]
# ## Composing the joint distribution

# %% [markdown]
# A multivariate distribution is defined by marginals and a copula.

# %%
X = ot.ComposedDistribution([WindDir_kde, U_dist, WaveDir_kde, Hs_dist, Tp_kde], bernstein_copula)
X_sample = X.getSample(N)
joint_df = pd.DataFrame(np.array(X_sample), columns=new_columns)
# Out:
# WRN - Warning! The description of the distribution ComposedDistribution is [v0,X0,v0,X0,v0] and cannot identify uniquely the marginal distribution. Use default description instead.

# %%
g = sns.PairGrid(joint_df, hue_kws={"alpha": [alpha], "marker": ["."]})
g = g.map_diag(sns.histplot, bins=20, color='C0')
g = g.map_lower(plt.scatter, color='C0')
g.data = joint_df.rank() / N * joint_df.max().values
g = g.map_upper(plt.scatter, color='C0')
g.savefig('figures/simulated_data.jpg', dpi=300);
